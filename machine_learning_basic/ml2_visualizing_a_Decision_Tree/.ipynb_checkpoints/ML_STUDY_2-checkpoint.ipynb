# %%
from sklearn.datasets import load_iris

# 1. import datasets
iris = load_iris()

print (iris.feature_names)
print (iris.target_names)
print (iris.data[0])
print( iris.target[0])

for i in range(len(iris.target)):
    print ("Example %d : lebel : %s, features : %s" % (i, iris.target[i], iris.data[i]))
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']
# [5.1 3.5 1.4 0.2]
# 0
# Example 0 : lebel : 0, features : [5.1 3.5 1.4 0.2]
# Example 1 : lebel : 0, features : [4.9 3.  1.4 0.2]
# Example 2 : lebel : 0, features : [4.7 3.2 1.3 0.2]
# Example 3 : lebel : 0, features : [4.6 3.1 1.5 0.2]
# Example 4 : lebel : 0, features : [5.  3.6 1.4 0.2]
# Example 5 : lebel : 0, features : [5.4 3.9 1.7 0.4]
# Example 6 : lebel : 0, features : [4.6 3.4 1.4 0.3]
# Example 7 : lebel : 0, features : [5.  3.4 1.5 0.2]
# Example 8 : lebel : 0, features : [4.4 2.9 1.4 0.2]
# Example 9 : lebel : 0, features : [4.9 3.1 1.5 0.1]
# Example 10 : lebel : 0, features : [5.4 3.7 1.5 0.2]
# Example 11 : lebel : 0, features : [4.8 3.4 1.6 0.2]
# Example 12 : lebel : 0, features : [4.8 3.  1.4 0.1]
# Example 13 : lebel : 0, features : [4.3 3.  1.1 0.1]
# Example 14 : lebel : 0, features : [5.8 4.  1.2 0.2]
# Example 15 : lebel : 0, features : [5.7 4.4 1.5 0.4]
# Example 16 : lebel : 0, features : [5.4 3.9 1.3 0.4]
# Example 17 : lebel : 0, features : [5.1 3.5 1.4 0.3]
# Example 18 : lebel : 0, features : [5.7 3.8 1.7 0.3]
# Example 19 : lebel : 0, features : [5.1 3.8 1.5 0.3]
# Example 20 : lebel : 0, features : [5.4 3.4 1.7 0.2]
# Example 21 : lebel : 0, features : [5.1 3.7 1.5 0.4]
# Example 22 : lebel : 0, features : [4.6 3.6 1.  0.2]
# Example 23 : lebel : 0, features : [5.1 3.3 1.7 0.5]
# Example 24 : lebel : 0, features : [4.8 3.4 1.9 0.2]
# Example 25 : lebel : 0, features : [5.  3.  1.6 0.2]
# Example 26 : lebel : 0, features : [5.  3.4 1.6 0.4]
# Example 27 : lebel : 0, features : [5.2 3.5 1.5 0.2]
# Example 28 : lebel : 0, features : [5.2 3.4 1.4 0.2]
# Example 29 : lebel : 0, features : [4.7 3.2 1.6 0.2]
# Example 30 : lebel : 0, features : [4.8 3.1 1.6 0.2]
# Example 31 : lebel : 0, features : [5.4 3.4 1.5 0.4]
# Example 32 : lebel : 0, features : [5.2 4.1 1.5 0.1]
# Example 33 : lebel : 0, features : [5.5 4.2 1.4 0.2]
# Example 34 : lebel : 0, features : [4.9 3.1 1.5 0.2]
# Example 35 : lebel : 0, features : [5.  3.2 1.2 0.2]
# Example 36 : lebel : 0, features : [5.5 3.5 1.3 0.2]
# Example 37 : lebel : 0, features : [4.9 3.6 1.4 0.1]
# Example 38 : lebel : 0, features : [4.4 3.  1.3 0.2]
# Example 39 : lebel : 0, features : [5.1 3.4 1.5 0.2]
# Example 40 : lebel : 0, features : [5.  3.5 1.3 0.3]
# Example 41 : lebel : 0, features : [4.5 2.3 1.3 0.3]
# Example 42 : lebel : 0, features : [4.4 3.2 1.3 0.2]
# Example 43 : lebel : 0, features : [5.  3.5 1.6 0.6]
# Example 44 : lebel : 0, features : [5.1 3.8 1.9 0.4]
# Example 45 : lebel : 0, features : [4.8 3.  1.4 0.3]
# Example 46 : lebel : 0, features : [5.1 3.8 1.6 0.2]
# Example 47 : lebel : 0, features : [4.6 3.2 1.4 0.2]
# Example 48 : lebel : 0, features : [5.3 3.7 1.5 0.2]
# Example 49 : lebel : 0, features : [5.  3.3 1.4 0.2]
# Example 50 : lebel : 1, features : [7.  3.2 4.7 1.4]
# Example 51 : lebel : 1, features : [6.4 3.2 4.5 1.5]
# Example 52 : lebel : 1, features : [6.9 3.1 4.9 1.5]
# Example 53 : lebel : 1, features : [5.5 2.3 4.  1.3]
# Example 54 : lebel : 1, features : [6.5 2.8 4.6 1.5]
# Example 55 : lebel : 1, features : [5.7 2.8 4.5 1.3]
# Example 56 : lebel : 1, features : [6.3 3.3 4.7 1.6]
# Example 57 : lebel : 1, features : [4.9 2.4 3.3 1. ]
# Example 58 : lebel : 1, features : [6.6 2.9 4.6 1.3]
# Example 59 : lebel : 1, features : [5.2 2.7 3.9 1.4]
# Example 60 : lebel : 1, features : [5.  2.  3.5 1. ]
# Example 61 : lebel : 1, features : [5.9 3.  4.2 1.5]
# Example 62 : lebel : 1, features : [6.  2.2 4.  1. ]
# Example 63 : lebel : 1, features : [6.1 2.9 4.7 1.4]
# Example 64 : lebel : 1, features : [5.6 2.9 3.6 1.3]
# Example 65 : lebel : 1, features : [6.7 3.1 4.4 1.4]
# Example 66 : lebel : 1, features : [5.6 3.  4.5 1.5]
# Example 67 : lebel : 1, features : [5.8 2.7 4.1 1. ]
# Example 68 : lebel : 1, features : [6.2 2.2 4.5 1.5]
# Example 69 : lebel : 1, features : [5.6 2.5 3.9 1.1]
# Example 70 : lebel : 1, features : [5.9 3.2 4.8 1.8]
# Example 71 : lebel : 1, features : [6.1 2.8 4.  1.3]
# Example 72 : lebel : 1, features : [6.3 2.5 4.9 1.5]
# Example 73 : lebel : 1, features : [6.1 2.8 4.7 1.2]
# Example 74 : lebel : 1, features : [6.4 2.9 4.3 1.3]
# Example 75 : lebel : 1, features : [6.6 3.  4.4 1.4]
# Example 76 : lebel : 1, features : [6.8 2.8 4.8 1.4]
# Example 77 : lebel : 1, features : [6.7 3.  5.  1.7]
# Example 78 : lebel : 1, features : [6.  2.9 4.5 1.5]
# Example 79 : lebel : 1, features : [5.7 2.6 3.5 1. ]
# Example 80 : lebel : 1, features : [5.5 2.4 3.8 1.1]
# Example 81 : lebel : 1, features : [5.5 2.4 3.7 1. ]
# Example 82 : lebel : 1, features : [5.8 2.7 3.9 1.2]
# Example 83 : lebel : 1, features : [6.  2.7 5.1 1.6]
# Example 84 : lebel : 1, features : [5.4 3.  4.5 1.5]
# Example 85 : lebel : 1, features : [6.  3.4 4.5 1.6]
# Example 86 : lebel : 1, features : [6.7 3.1 4.7 1.5]
# Example 87 : lebel : 1, features : [6.3 2.3 4.4 1.3]
# Example 88 : lebel : 1, features : [5.6 3.  4.1 1.3]
# Example 89 : lebel : 1, features : [5.5 2.5 4.  1.3]
# Example 90 : lebel : 1, features : [5.5 2.6 4.4 1.2]
# Example 91 : lebel : 1, features : [6.1 3.  4.6 1.4]
# Example 92 : lebel : 1, features : [5.8 2.6 4.  1.2]
# Example 93 : lebel : 1, features : [5.  2.3 3.3 1. ]
# Example 94 : lebel : 1, features : [5.6 2.7 4.2 1.3]
# Example 95 : lebel : 1, features : [5.7 3.  4.2 1.2]
# Example 96 : lebel : 1, features : [5.7 2.9 4.2 1.3]
# Example 97 : lebel : 1, features : [6.2 2.9 4.3 1.3]
# Example 98 : lebel : 1, features : [5.1 2.5 3.  1.1]
# Example 99 : lebel : 1, features : [5.7 2.8 4.1 1.3]
# Example 100 : lebel : 2, features : [6.3 3.3 6.  2.5]
# Example 101 : lebel : 2, features : [5.8 2.7 5.1 1.9]
# Example 102 : lebel : 2, features : [7.1 3.  5.9 2.1]
# Example 103 : lebel : 2, features : [6.3 2.9 5.6 1.8]
# Example 104 : lebel : 2, features : [6.5 3.  5.8 2.2]
# Example 105 : lebel : 2, features : [7.6 3.  6.6 2.1]
# Example 106 : lebel : 2, features : [4.9 2.5 4.5 1.7]
# Example 107 : lebel : 2, features : [7.3 2.9 6.3 1.8]
# Example 108 : lebel : 2, features : [6.7 2.5 5.8 1.8]
# Example 109 : lebel : 2, features : [7.2 3.6 6.1 2.5]
# Example 110 : lebel : 2, features : [6.5 3.2 5.1 2. ]
# Example 111 : lebel : 2, features : [6.4 2.7 5.3 1.9]
# Example 112 : lebel : 2, features : [6.8 3.  5.5 2.1]
# Example 113 : lebel : 2, features : [5.7 2.5 5.  2. ]
# Example 114 : lebel : 2, features : [5.8 2.8 5.1 2.4]
# Example 115 : lebel : 2, features : [6.4 3.2 5.3 2.3]
# Example 116 : lebel : 2, features : [6.5 3.  5.5 1.8]
# Example 117 : lebel : 2, features : [7.7 3.8 6.7 2.2]
# Example 118 : lebel : 2, features : [7.7 2.6 6.9 2.3]
# Example 119 : lebel : 2, features : [6.  2.2 5.  1.5]
# Example 120 : lebel : 2, features : [6.9 3.2 5.7 2.3]
# Example 121 : lebel : 2, features : [5.6 2.8 4.9 2. ]
# Example 122 : lebel : 2, features : [7.7 2.8 6.7 2. ]
# Example 123 : lebel : 2, features : [6.3 2.7 4.9 1.8]
# Example 124 : lebel : 2, features : [6.7 3.3 5.7 2.1]
# Example 125 : lebel : 2, features : [7.2 3.2 6.  1.8]
# Example 126 : lebel : 2, features : [6.2 2.8 4.8 1.8]
# Example 127 : lebel : 2, features : [6.1 3.  4.9 1.8]
# Example 128 : lebel : 2, features : [6.4 2.8 5.6 2.1]
# Example 129 : lebel : 2, features : [7.2 3.  5.8 1.6]
# Example 130 : lebel : 2, features : [7.4 2.8 6.1 1.9]
# Example 131 : lebel : 2, features : [7.9 3.8 6.4 2. ]
# Example 132 : lebel : 2, features : [6.4 2.8 5.6 2.2]
# Example 133 : lebel : 2, features : [6.3 2.8 5.1 1.5]
# Example 134 : lebel : 2, features : [6.1 2.6 5.6 1.4]
# Example 135 : lebel : 2, features : [7.7 3.  6.1 2.3]
# Example 136 : lebel : 2, features : [6.3 3.4 5.6 2.4]
# Example 137 : lebel : 2, features : [6.4 3.1 5.5 1.8]
# Example 138 : lebel : 2, features : [6.  3.  4.8 1.8]
# Example 139 : lebel : 2, features : [6.9 3.1 5.4 2.1]
# Example 140 : lebel : 2, features : [6.7 3.1 5.6 2.4]
# Example 141 : lebel : 2, features : [6.9 3.1 5.1 2.3]
# Example 142 : lebel : 2, features : [5.8 2.7 5.1 1.9]
# Example 143 : lebel : 2, features : [6.8 3.2 5.9 2.3]
# Example 144 : lebel : 2, features : [6.7 3.3 5.7 2.5]
# Example 145 : lebel : 2, features : [6.7 3.  5.2 2.3]
# Example 146 : lebel : 2, features : [6.3 2.5 5.  1.9]
# Example 147 : lebel : 2, features : [6.5 3.  5.2 2. ]
# Example 148 : lebel : 2, features : [6.2 3.4 5.4 2.3]
# Example 149 : lebel : 2, features : [5.9 3.  5.1 1.8]

# %%
# 2. Train classifier
import numpy as np
from sklearn.datasets import load_iris
from sklearn import tree

test_idx = [0, 50, 100]

# training data
train_target = np.delete(iris.target, test_idx)
train_data = np.delete(iris.data, test_idx, axis=0)

# testing data
test_target = iris.target[test_idx]
test_data = iris.data[test_idx]

# %%
# 3. Predict label for new flower
clf = tree.DecisionTreeClassifier()
clf.fit(train_data, train_target)

print (test_target)
print (clf.predict(test_data))
# Out:
# [0 1 2]
# [0 1 2]

# %%
# 4. Visualize for tree
import pydot
from io import StringIO
from IPython.display import Image

dot_data = StringIO()
tree.export_graphviz(clf,
                        out_file=dot_data,
                        feature_names=iris.feature_names,
                        class_names=iris.target_names,
                        filled=True, rounded=True,
                        impurity=False)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph[0].create_png())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\jongm\appdata\local\programs\python\python38-32\lib\site-packages\pydot.py in create(self, prog, format, encoding)
#    1911         try:
# -> 1912             stdout_data, stderr_data, process = call_graphviz(
#    1913                 program=prog,
#
# c:\users\jongm\appdata\local\programs\python\python38-32\lib\site-packages\pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     128
# --> 129     process = subprocess.Popen(
#     130         program_with_args,
#
# c:\users\jongm\appdata\local\programs\python\python38-32\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# c:\users\jongm\appdata\local\programs\python\python38-32\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1306             try:
# -> 1307                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1308                                          # no special security
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-392eca2d02ae> in <module>
#      12                         impurity=False)
#      13 graph = pydot.graph_from_dot_data(dot_data.getvalue())
# ---> 14 Image(graph[0].create_png())
#
# c:\users\jongm\appdata\local\programs\python\python38-32\lib\site-packages\pydot.py in new_method(f, prog, encoding)
#    1720                     encoding=None):
#    1721                 """Refer to docstring of method `create`."""
# -> 1722                 return self.create(
#    1723                     format=f, prog=prog, encoding=encoding)
#    1724             name = 'create_{fmt}'.format(fmt=frmt)
#
# c:\users\jongm\appdata\local\programs\python\python38-32\lib\site-packages\pydot.py in create(self, prog, format, encoding)
#    1920                 args[1] = '"{prog}" not found in path.'.format(
#    1921                     prog=prog)
# -> 1922                 raise OSError(*args)
#    1923             else:
#    1924                 raise
#
# FileNotFoundError: [WinError 2] "dot" not found in path.
